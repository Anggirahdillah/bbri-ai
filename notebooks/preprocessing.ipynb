# %% [markdown]
# ## **Import & Setup**

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## **1. Load Dataset**

# %%
df = pd.read_csv("data_saham_bbri_jk.csv")
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)

print(df.head())
# Out:
#         date        close         high          low         open     volume
# 0 2020-01-02  2853.532471  2853.532471  2821.179426  2847.061827   45886302
# 1 2020-01-03  2860.002686  2872.943972  2840.590930  2860.002686   91189705
# 2 2020-01-06  2827.649902  2840.591015  2795.296860  2821.179259   48648450
# 3 2020-01-07  2847.061768  2853.532411  2834.120654  2853.532411  114344885
# 4 2020-01-08  2834.120850  2847.061964  2808.238448  2834.120850  188929583

# %% [markdown]
# ## **2. Data Cleaning**

# %%
# Hapus missing values
df = df.dropna()

# Pastikan tipe data numeric
numeric_cols = ['open', 'high', 'low', 'close', 'volume']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

df = df.dropna(subset=numeric_cols)

# Hapus duplikat tanggal
df = df.drop_duplicates(subset=['date']).reset_index(drop=True)

df_clean = df.copy()
df_clean.to_csv("df_clean_bbri.csv", index=False)
df_clean.head()
# Out:
#         date        close         high          low         open     volume
# 0 2020-01-02  2853.532471  2853.532471  2821.179426  2847.061827   45886302
# 1 2020-01-03  2860.002686  2872.943972  2840.590930  2860.002686   91189705
# 2 2020-01-06  2827.649902  2840.591015  2795.296860  2821.179259   48648450
# 3 2020-01-07  2847.061768  2853.532411  2834.120654  2853.532411  114344885
# 4 2020-01-08  2834.120850  2847.061964  2808.238448  2834.120850  188929583

# %% [markdown]
# ## **3. Feature Engineering**

# %% [markdown]
# **3.1 Moving Average**

# %%
df_clean["MA7"] = df_clean["close"].rolling(window=7).mean()
df_clean["MA14"] = df_clean["close"].rolling(window=14).mean()
df_clean["MA30"] = df_clean["close"].rolling(window=30).mean()

# %% [markdown]
# **3.2 Return**

# %%
df_clean["returns"] = df_clean["close"].pct_change()

# %% [markdown]
# **3.3 RSI**

# %%
def compute_rsi(series, period=14):
    delta = series.diff()
    gain = np.where(delta > 0, delta, 0)
    loss = np.where(delta < 0, -delta, 0)

    avg_gain = pd.Series(gain).rolling(period).mean()
    avg_loss = pd.Series(loss).rolling(period).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

df_clean["RSI14"] = compute_rsi(df_clean["close"])

# %% [markdown]
# **3.4 MACD**

# %%
ema12 = df_clean["close"].ewm(span=12, adjust=False).mean()
ema26 = df_clean["close"].ewm(span=26, adjust=False).mean()

df_clean["MACD"] = ema12 - ema26
df_clean["MACD_signal"] = df_clean["MACD"].ewm(span=9, adjust=False).mean()
df_clean["MACD_hist"] = df_clean["MACD"] - df_clean["MACD_signal"]

# %% [markdown]
# **3.5 Lag Features**

# %%
df_clean["lag1"] = df_clean["close"].shift(1)
df_clean["lag3"] = df_clean["close"].shift(3)
df_clean["lag7"] = df_clean["close"].shift(7)

# %% [markdown]
# **Final Prep**

# %%
df_prepared = df_clean.dropna().reset_index(drop=True)
df_prepared.to_csv("df_prepared_bbri.csv", index=False)
df_prepared.head()
# Out:
#         date        close         high          low         open     volume  \
# 0 2020-02-12  2931.179199  2950.590779  2924.708557  2924.708557  143167912
# 1 2020-02-13  2957.062012  2970.003299  2937.650428  2963.532656   87683284
# 2 2020-02-14  2944.120361  2970.002934  2931.179423  2931.179423  139707803
# 3 2020-02-17  2892.355713  2937.650040  2892.355713  2898.826356  131738165
# 4 2020-02-18  2847.061768  2911.767681  2847.061768  2892.355925   97565635
#
#            MA7         MA14         MA30   returns      RSI14      MACD  \
# 0  2935.801095  2952.902012  2940.238241  0.004434  27.659429  2.451033
# 1  2936.725551  2945.044870  2943.689225  0.008830  33.333309  3.589504
# 2  2935.801200  2940.423026  2946.493148 -0.004377  38.636354  3.408180
# 3  2928.406250  2933.490252  2948.650008 -0.017582  34.693852 -0.902096
# 4  2914.540737  2923.322196  2948.650008 -0.015660  30.357130 -7.882005
#
#    MACD_signal  MACD_hist         lag1         lag3         lag7
# 0    12.679836 -10.228803  2918.238525  2944.120361  2885.885498
# 1    10.861769  -7.272266  2931.179199  2911.767578  2950.590820
# 2     9.371051  -5.962872  2957.062012  2918.238525  2950.590820
# 3     7.316422  -8.218518  2944.120361  2931.179199  2944.120361
# 4     4.276736 -12.158742  2892.355713  2957.062012  2944.120361

# %% [markdown]
# ## **(EDA 1) Tren Harga Saham**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df_clean['date'], df_clean['close'])
plt.title('Tren Harga Saham BBRI')
plt.xlabel('Tanggal')
plt.ylabel('Harga Penutupan')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## **(EDA 2) Volume Perdagangan**

# %%
plt.figure(figsize=(12,5))
plt.plot(df_clean['date'], df_clean['volume'])
plt.title('Volume Perdagangan Saham BBRI')
plt.xlabel('Tanggal')
plt.ylabel('Volume')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## **(EDA 3) Moving Average vs Harga**

# %%
plt.figure(figsize=(12,5))
plt.plot(df_clean['date'], df_clean['close'], label='Close')
plt.plot(df_clean['date'], df_clean['MA7'], label='MA7')
plt.plot(df_clean['date'], df_clean['MA14'], label='MA14')
plt.plot(df_clean['date'], df_clean['MA30'], label='MA30')
plt.title('Harga Saham dan Moving Average')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## **(EDA 4) Distribusi Return**

# %%
plt.figure(figsize=(8,4))
df_clean['returns'].dropna().hist(bins=50)
plt.title('Distribusi Return Harian Saham BBRI')
plt.xlabel('Return')
plt.ylabel('Frekuensi')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## **4. Split (Train / Validation / Test)**

# %%
train_size = int(len(df_prepared)*0.7)
val_size = int(len(df_prepared)*0.15)

train = df_prepared.iloc[:train_size]
val = df_prepared.iloc[train_size:train_size+val_size]
test = df_prepared.iloc[train_size+val_size:]

train.to_csv("train_bbri.csv", index=False)
val.to_csv("val_bbri.csv", index=False)
test.to_csv("test_bbri.csv", index=False)
